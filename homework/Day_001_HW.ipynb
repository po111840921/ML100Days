# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, y_hat):
    
    MSE = sum((y-y_hat) ** 2) / len(y)
    return MSE

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 211.250
# The Mean absolute error is 11.410

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
#     我選擇的是Fake and real news dataset這組data。網址：https://www.kaggle.com/clmentbisaillon/fake-and-real-news-dataset
#
# 1. 你選的這組資料為何重要
#
#     這組資料目的在於透過機器學習方法，在給予何者是真新聞，何者是假新聞的不同資料下，讓機器學習在給定一個新資料之下預測它是真的還是假的。之所以重要，因為現在假新聞氾濫，若能在給予一則新聞能夠過濾掉假新聞，或者有類似的提醒，可以降低民眾被誤導的機率。
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#     資料以擷取美國新聞的方式，將新聞的標題、本文、類別、時間擷取下來，並分別為真新聞或者是假新聞。
#
# 3. 蒐集而來的資料型態為何
#
#     資料的型態為csv，可以簡單的運用python中套件pandas，read_csv函數就可以輕鬆讀取。但比較困難的是，裡面都是字串，不管是標題還是本文，所以這方面要用文字分析的模型來做處理，ex:詞袋模型等等。
#
# 4. 這組資料想解決的問題如何評估
#
#     這個問題是，要如何製作一個機器學習的工具來分辨真假新聞。我想可以運用詞袋模型，將新聞中出現的詞彙分門別類，並製作出一個向量，並運用比例的方式，結合計量模型來做預測。ex:某一些詞類在新聞中出現的多，則被認定為假新聞。
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#     要能提升業績，很簡單衡量的就是收入減支出，定義為淨利，再去除以工作的時間，可以得到每一小時淨利這樣的指標，我們再以這個指標為主，去極大化這個目標。也就是說，或許藉由調整出去載客的時間、擴大車隊等等，可以將每小時淨利提高。所以我的假設是，找到人口密度最高、人潮聚集最多的時間，並以這個時段、區域來當作每次載客的因子。
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#     我們可以找出全台灣每個城市的人口密度圖並分門別類，比方說同一個縣市依照人口密度排一到十等等；另外找出在那個區域中，每小時的車流量，這部分或許可以透過記錄google地圖的狀況來得到資料。而被解釋變數，如果能得到每小時該地區uber或計程車估算的收入，則可以代表為一個被解釋變數。
#
#
# 3. 蒐集而來的資料型態為何
#
#     期待蒐集到的資料為表格、csv格式，google的部分可能要接api並且經由python處理為csv。
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#     跑複回歸，並且看看係數、模型顯不顯著，來評斷這些因子是不是重要的因子。
